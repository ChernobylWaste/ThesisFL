# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(".\Fix CICIoT2023 10%.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\Just Mine\AppData\Local\Temp\ipykernel_8488\2278516931.py:1: SyntaxWarning: invalid escape sequence '\F'
#   df = pd.read_csv(".\Fix CICIoT2023 10%.csv")

# %%
print("Shape Dataset:", df.shape)
# Out:
# Shape Dataset: (4644782, 47)

# %%
print("Jumlah duplikat:", df.duplicated().sum())
# Out:
# Jumlah duplikat: 1016288

# %%
print("Jumlah missing value per kolom:\n", df.isnull().sum())
# Out:
# Jumlah missing value per kolom:
#  flow_duration      0
# Header_Length      0
# Protocol Type      0
# Duration           0
# Rate               0
# Srate              0
# Drate              0
# fin_flag_number    0
# syn_flag_number    0
# rst_flag_number    0
# psh_flag_number    0
# ack_flag_number    0
# ece_flag_number    0
# cwr_flag_number    0
# ack_count          0
# syn_count          0
# fin_count          0
# urg_count          0
# rst_count          0
# HTTP               0
# HTTPS              0
# DNS                0
# Telnet             0
# SMTP               0
# SSH                0
# IRC                0
# TCP                0
# UDP                0
# DHCP               0
# ARP                0
# ICMP               0
# IPv                0
# LLC                0
# Tot sum            0
# Min                0
# Max                0
# AVG                0
# Std                0
# Tot size           0
# IAT                0
# Number             0
# Magnitue           0
# Radius             0
# Covariance         0
# Variance           0
# Weight             0
# Attack Type        0
# dtype: int64

# %%
df_clean = df.drop_duplicates().dropna()
print("Shape sesudah cleaning:", df_clean.shape)
# Out:
# Shape sesudah cleaning: (3628494, 47)

# %%
print('Nama Kolom :')
print(df_clean.columns)
# Out:
# Nama Kolom :
# Index(['flow_duration', 'Header_Length', 'Protocol Type', 'Duration', 'Rate',
#        'Srate', 'Drate', 'fin_flag_number', 'syn_flag_number',
#        'rst_flag_number', 'psh_flag_number', 'ack_flag_number',
#        'ece_flag_number', 'cwr_flag_number', 'ack_count', 'syn_count',
#        'fin_count', 'urg_count', 'rst_count', 'HTTP', 'HTTPS', 'DNS', 'Telnet',
#        'SMTP', 'SSH', 'IRC', 'TCP', 'UDP', 'DHCP', 'ARP', 'ICMP', 'IPv', 'LLC',
#        'Tot sum', 'Min', 'Max', 'AVG', 'Std', 'Tot size', 'IAT', 'Number',
#        'Magnitue', 'Radius', 'Covariance', 'Variance', 'Weight',
#        'Attack Type'],
#       dtype='object')

# %%
print("Jumlah Serangan Pada Dataset: \n")
df_clean['Attack Type'].value_counts()
# Out:
# Jumlah Serangan Pada Dataset:
# Attack Type
# DDoS              2450878
# DoS                737932
# Mirai              242314
# BENIGN             109198
# Network Attack      53730
# Recon               31732
# Brute Force          1288
# Injection            1114
# Malware               308
# Name: count, dtype: int64

# %%
df_clean.describe().transpose()
# Out:
#                      count          mean           std        min  \
# flow_duration    3628494.0  7.262134e+00  3.572647e+02   0.000000
# Header_Length    3628494.0  9.806348e+04  5.193582e+05   0.000000
# Protocol Type    3628494.0  1.013753e+01  9.241336e+00   0.000000
# Duration         3628494.0  6.701270e+01  1.581393e+01   0.000000
# Rate             3628494.0  8.175992e+03  8.229018e+04   0.000000
# Srate            3628494.0  8.175992e+03  8.229018e+04   0.000000
# Drate            3628494.0  7.574018e-06  7.216878e-03   0.000000
# fin_flag_number  3628494.0  6.010097e-02  2.376738e-01   0.000000
# syn_flag_number  3628494.0  2.288150e-01  4.200700e-01   0.000000
# rst_flag_number  3628494.0  6.517856e-02  2.468407e-01   0.000000
# psh_flag_number  3628494.0  7.579481e-02  2.646696e-01   0.000000
# ack_flag_number  3628494.0  1.215714e-01  3.267902e-01   0.000000
# ece_flag_number  3628494.0  3.307157e-06  1.818556e-03   0.000000
# cwr_flag_number  3628494.0  2.204771e-06  1.484846e-03   0.000000
# ack_count        3628494.0  6.519731e-02  2.461582e-01   0.000000
# syn_count        3628494.0  3.865722e-01  7.196182e-01   0.000000
# fin_count        3628494.0  7.630373e-02  3.077427e-01   0.000000
# urg_count        3628494.0  7.962352e+00  8.140189e+01   0.000000
# rst_count        3628494.0  4.921917e+01  3.673750e+02   0.000000
# HTTP             3628494.0  4.801992e-02  2.138084e-01   0.000000
# HTTPS            3628494.0  6.202050e-02  2.411928e-01   0.000000
# DNS              3628494.0  1.584679e-04  1.258741e-02   0.000000
# Telnet           3628494.0  0.000000e+00  0.000000e+00   0.000000
# SMTP             3628494.0  0.000000e+00  0.000000e+00   0.000000
# SSH              3628494.0  5.098534e-05  7.140221e-03   0.000000
# IRC              3628494.0  2.755964e-07  5.249728e-04   0.000000
# TCP              3628494.0  5.592516e-01  4.964769e-01   0.000000
# UDP              3628494.0  2.674448e-01  4.426264e-01   0.000000
# DHCP             3628494.0  1.653579e-06  1.285915e-03   0.000000
# ARP              3628494.0  8.571049e-05  9.257601e-03   0.000000
# ICMP             3628494.0  1.141107e-01  3.179457e-01   0.000000
# IPv              3628494.0  9.998523e-01  1.215310e-02   0.000000
# LLC              3628494.0  9.998523e-01  1.215310e-02   0.000000
# Tot sum          3628494.0  1.494168e+03  2.907092e+03  42.000000
# Min              3628494.0  1.000590e+02  1.521860e+02  42.000000
# Max              3628494.0  2.158557e+02  5.898410e+02  42.000000
# AVG              3628494.0  1.423631e+02  2.673506e+02  42.000000
# Std              3628494.0  4.264992e+01  1.806642e+02   0.000000
# Tot size         3628494.0  1.423638e+02  2.679245e+02  42.000000
# IAT              3628494.0  8.318577e+07  1.931527e+07   0.000000
# Number           3628494.0  9.498648e+00  9.282705e-01   1.000000
# Magnitue         3628494.0  1.384743e+01  9.461430e+00   9.165152
# Radius           3628494.0  6.027347e+01  2.555249e+02   0.000000
# Covariance       3628494.0  3.945122e+04  3.691114e+05   0.000000
# Variance         3628494.0  1.233854e-01  2.572398e-01   0.000000
# Weight           3628494.0  1.415170e+02  2.387380e+01   1.000000
#
#                           25%           50%           75%           max
# flow_duration    0.000000e+00  1.471647e-02  2.321106e-01  3.943572e+05
# Header_Length    5.400000e+01  7.180000e+01  1.375600e+04  9.831137e+06
# Protocol Type    6.000000e+00  6.000000e+00  1.684000e+01  4.700000e+01
# Duration         6.400000e+01  6.400000e+01  6.400000e+01  2.550000e+02
# Rate             2.199600e+00  1.893449e+01  8.567482e+02  8.388608e+06
# Srate            2.199600e+00  1.893449e+01  8.567482e+02  8.388608e+06
# Drate            0.000000e+00  0.000000e+00  0.000000e+00  1.336830e+01
# fin_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# syn_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# rst_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# psh_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ack_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ece_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# cwr_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ack_count        0.000000e+00  0.000000e+00  0.000000e+00  5.100000e+00
# syn_count        0.000000e+00  0.000000e+00  9.500000e-01  1.287000e+01
# fin_count        0.000000e+00  0.000000e+00  0.000000e+00  7.880000e+01
# urg_count        0.000000e+00  0.000000e+00  0.000000e+00  4.260400e+03
# rst_count        0.000000e+00  0.000000e+00  3.000000e-02  9.606500e+03
# HTTP             0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# HTTPS            0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# DNS              0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# Telnet           0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# SMTP             0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# SSH              0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# IRC              0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# TCP              0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# UDP              0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# DHCP             0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ARP              0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ICMP             0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# IPv              1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# LLC              1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# Tot sum          5.250000e+02  5.670000e+02  5.708000e+02  1.208921e+05
# Min              5.000000e+01  5.400000e+01  5.400000e+01  7.306000e+03
# Max              5.130000e+01  5.400000e+01  5.994000e+01  4.181400e+04
# AVG              5.004340e+01  5.400000e+01  5.441405e+01  8.040961e+03
# Std              0.000000e+00  0.000000e+00  1.092795e+00  1.034054e+04
# Tot size         5.010000e+01  5.400000e+01  5.450000e+01  9.430300e+03
# IAT              8.303769e+07  8.310670e+07  8.334421e+07  1.676394e+08
# Number           9.500000e+00  9.500000e+00  9.500000e+00  1.500000e+01
# Magnitue         1.000397e+01  1.039230e+01  1.042953e+01  1.252094e+02
# Radius           0.000000e+00  0.000000e+00  1.544983e+00  1.464463e+04
# Covariance       0.000000e+00  0.000000e+00  8.568347e+00  1.077896e+08
# Variance         0.000000e+00  0.000000e+00  1.300000e-01  1.000000e+00
# Weight           1.415500e+02  1.415500e+02  1.415500e+02  2.446000e+02

# %%
# Bersihkan dan konversi ke lowercase
df_clean['Attack Type Clean'] = df_clean['Attack Type'].astype(str).str.strip().str.lower()

# Konversi label: 0 jika benign, 1 untuk serangan lainnya
df_clean['Attack'] = df_clean['Attack Type Clean'].apply(lambda x: 0 if x == 'benign' else 1)

# Tampilkan distribusi hasil konversi
print("\nDistribusi biner Attack setelah perbaikan:")
print(df_clean['Attack'].value_counts())
# Out:
# Distribusi biner Attack setelah perbaikan:
# Attack
# 1    3519296
# 0     109198
# Name: count, dtype: int64

# %%
correlation = df_clean.corr(numeric_only=True)
corr_attack = correlation['Attack'].drop('Attack').sort_values(ascending=False)

# %%
# Korelasi Antar Fitur

corr = df_clean.corr(numeric_only = True).round(2)
corr.style.background_gradient(cmap = 'coolwarm', axis = None).format(precision = 2)
# Out:
# <style type="text/css">
# #T_645d2_row0_col0, #T_645d2_row1_col1, #T_645d2_row2_col2, #T_645d2_row3_col3, #T_645d2_row4_col4, #T_645d2_row4_col5, #T_645d2_row5_col4, #T_645d2_row5_col5, #T_645d2_row6_col6, #T_645d2_row7_col7, #T_645d2_row8_col8, #T_645d2_row9_col9, #T_645d2_row10_col10, #T_645d2_row11_col11, #T_645d2_row12_col12, #T_645d2_row13_col13, #T_645d2_row14_col14, #T_645d2_row15_col15, #T_645d2_row16_col16, #T_645d2_row17_col
46, #T_645d2_row7_col4, #T_645d2_row7_col5, #T_645d2_row7_col6, #T_645d2_row7_col12, #T_645d2_row7_col13, #T_645d2_row7_col20, #T_645d2_row7_col21, #T_645d2_row7_col24, #T_645d2_row7_col25, #T_645d2_row7_col28, #T_645d2_row7_col29, #T_645d2_row7_col31, #T_645d2_row7_col32, #T_645d2_row7_col39, #T_645d2_row7_col40, #T_645d2_row7_col45, #T_645d2_row8_col6, #T_645d2_row8_col12, #T_645d2_row8_col13, #T_645d2_row8_col24, #T_645d2_row8_col25, #T_645d2_row8_col28, #T_645d2_row8_col39, #T_645d2_row8_col40, #T_645d2_row8_col45, #T_645d2_row9_col6, #T_645d2_row9_col12, #T_645d2_row9_col13, #T_645d2_row9_col20, #T_645d2_row9_col21, #T_645d2_row9_col24, #T_645d2_row9_col25, #T_645d2_row9_col28, #T_645d2_row9_col29, #T_645d2_row9_col31, #T_645d2_row9_col32, #T_645d2_row9_col39, #T_645d2_row9_col40, #T_645d2_row9_col45, #T_645d2_row10_col0, #T_645d2_row10_col6, #T_645d2_row10_col12, #T_645d2_row10_col13, #T_645d2_row10_col21, #T_645d2_row10_col24, #T_645d2_row10_col25, #T_645d2_row10_col28, #T_645d2_row10_col29, #T_645d2_row10_col31, #T_645d2_row10_col32, #T_645d2_row10_col39, #T_645d2_row10_col40, #T_645d2_row10_col45, #T_645d2_row11_col6, #T_645d2_row11_col12, #T_645d2_row11_col13, #T_645d2_row11_col21, #T_645d2_row11_col25, #T_645d2_row11_col28,  ...

# %%
positively_correlated_features = corr_attack[corr_attack > 0]
print("\nFitur-fitur yang berkorelasi positif dengan serangan (Attack):")
print(positively_correlated_features)
# Out:
# Fitur-fitur yang berkorelasi positif dengan serangan (Attack):
# syn_flag_number    0.095934
# UDP                0.079581
# ICMP               0.063220
# Protocol Type      0.050417
# rst_flag_number    0.046499
# fin_flag_number    0.044536
# psh_flag_number    0.038907
# fin_count          0.036225
# ack_count          0.015550
# Srate              0.013313
# Rate               0.013313
# HTTP               0.008153
# IPv                0.007947
# LLC                0.007947
# SSH                0.001258
# ece_flag_number    0.000320
# cwr_flag_number    0.000262
# DHCP               0.000227
# Drate              0.000185
# IRC                0.000092
# Name: Attack, dtype: float64

# %%
plt.figure(figsize=(10, len(corr_attack) // 2))
sns.heatmap(corr_attack.to_frame(), annot=True, cmap='Reds')
plt.title("Correlation of Features with Attack")
plt.show()

# %%
# Daftar fitur yang ingin ditampilkan (urutkan sesuai urutan yang kamu berikan)
selected_features = [
    "syn_flag_number",
    "UDP",
    "ICMP",
    "Protocol Type",
    "rst_flag_number",
    "fin_flag_number",
    "psh_flag_number",
    "fin_count",
    "ack_count",
    "Srate",
    "Rate",
    "HTTP",
    "IPv",
    "LLC",
    "SSH",
    "ece_flag_number",
    "cwr_flag_number",
    "DHCP",
    "Drate",
    "IRC"
]

# Ambil subset dari Series corr_attack
subset_corr = corr_attack.loc[selected_features]

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(subset_corr.to_frame(), annot=True, cmap='Reds', cbar=True)
plt.title("Correlation of Top 20 Features with Attack Labels")
plt.tight_layout()
plt.show()
