# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
# Out:
# 2025-07-07 12:25:37.702011: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-07 12:25:37.732518: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-07 12:25:37.733433: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-07 12:25:38.297466: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
dataset = pd.read_csv("/home/mbc/thesissatria/Dataset/CICIoT2023 rows 1814248 _39%, 38%, 38%, 60%, 35%, 30%, 3%, 3%, 3%.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1814248 entries, 0 to 1814247
# Data columns (total 47 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   flow_duration    float64
#  1   Header_Length    float64
#  2   Protocol Type    float64
#  3   Duration         float64
#  4   Rate             float64
#  5   Srate            float64
#  6   Drate            float64
#  7   fin_flag_number  float64
#  8   syn_flag_number  float64
#  9   rst_flag_number  float64
#  10  psh_flag_number  float64
#  11  ack_flag_number  float64
#  12  ece_flag_number  float64
#  13  cwr_flag_number  float64
#  14  ack_count        float64
#  15  syn_count        float64
#  16  fin_count        float64
#  17  urg_count        float64
#  18  rst_count        float64
#  19  HTTP             float64
#  20  HTTPS            float64
#  21  DNS              float64
#  22  Telnet           float64
#  23  SMTP             float64
#  24  SSH              float64
#  25  IRC              float64
#  26  TCP              float64
#  27  UDP              float64
#  28  DHCP             float64
#  29  ARP              float64
#  30  ICMP             float64
#  31  IPv              float64
#  32  LLC              float64
#  33  Tot sum          float64
#  34  Min              float64
#  35  Max              float64
#  36  AVG              float64
#  37  Std              float64
#  38  Tot size         float64
#  39  IAT              float64
#  40  Number           float64
#  41  Magnitue         float64
#  42  Radius           float64
#  43  Covariance       float64
#  44  Variance         float64
#  45  Weight           float64
#  46  Attack Type      object
# dtypes: float64(46), object(1)
# memory usage: 650.6+ MB

# %%
print("Ukuran Dataset Sebelum Drop Duplikat dan Missing Value:")
dataset.shape
# Out:
# Ukuran Dataset Sebelum Drop Duplikat dan Missing Value:
# (1814248, 47)

# %%
dups = dataset[dataset.duplicated()]
print(f'Jumlah Duplikat: {len(dups)}')
# Out:
# Jumlah Duplikat: 0

# %%
missing_val = dataset.isna().sum()
print(missing_val.loc[missing_val > 0])

numeric_cols = dataset.select_dtypes(include = np.number).columns
inf_count = np.isinf(dataset[numeric_cols]).sum()
print(inf_count[inf_count > 0])

print(f'Nilai Hilang {dataset.isna().sum().sum()}')
# Out:
# Series([], dtype: int64)
# Series([], dtype: int64)
# Nilai Hilang 0

# %%
print("Ukuran Dataset Sesudah Drop Duplikat:")
dataset.drop_duplicates(inplace = True)
dataset.shape
# Out:
# Ukuran Dataset Sesudah Drop Duplikat:
# (1814248, 47)

# %%
dataset.describe().transpose()
# Out:
#                      count          mean           std        min  \
# flow_duration    1814248.0  7.303477e+00  4.149601e+02   0.000000
# Header_Length    1814248.0  1.056503e+05  5.348541e+05   0.000000
# Protocol Type    1814248.0  1.008240e+01  9.169028e+00   0.000000
# Duration         1814248.0  6.744882e+01  1.711258e+01   0.000000
# Rate             1814248.0  8.091609e+03  8.138155e+04   0.000000
# Srate            1814248.0  8.091609e+03  8.138155e+04   0.000000
# Drate            1814248.0  1.034936e-05  9.979925e-03   0.000000
0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# syn_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# rst_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# psh_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ack_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ece_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# cwr_flag_number  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ack_count        0.000000e+00  0.000000e+00  0.000000e+00  4.700000e+00
# syn_count        0.000000e+00  0.000000e+00  9.700000e-01  1.222000e+01
# fin_count        0.000000e+00  0.000000e+00  0.000000e+00  7.880000e+01
# urg_count        0.000000e+00  0.000000e+00  0.000000e+00  4.260400e+03
# rst_count        0.000000e+00  0.000000e+00  3.000000e-02  9.566500e+03
# HTTP             0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# HTTPS            0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# DNS              0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# Telnet           0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# SMTP             0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# SSH              0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# IRC              0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# TCP              0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# UDP              0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# DHCP             0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ARP              0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ICMP             0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# IPv              1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# LLC              1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# Tot sum          5.251000e+02  5.670000e+02  5.713200e+02  1.208921e+05
# Min              5.000000e+01  5.400000e+01  5.400000e+01  3.830800e+03
# Max              5.140000e+01  5.400000e+01  6.100000e+01  3.047400e+04
# AVG              5.005216e+01  5.400000e+01  5.449357e+01  8.040961e+03
# Std              0.000000e+00  0.000000e+00  1.191398e+00  7.783121e+03
# Tot size         5.010000e+01  5.400000e+01  5.463000e+01  9.430300e+03
# IAT              8.303770e+07  8.310690e+07  8.334426e+07  1.676394e+08
# Number           9.500000e+00  9.500000e+00  9.500000e+00  1.500000e+01
# Magnitue         1.000496e+01  1.039230e+01  1.043674e+01  1.252094e+02
# Radius           0.000000e+00  0.000000e+00  1.682731e+00  1.100700e+04
# Covariance       0.000000e+00  0.000000e+00  1.011373e+01  6.910586e+07
# Variance         0.000000e+00  0.000000e+00  1.300000e-01  1.000000e+00
# Weight           1.415500e+02  1.415500e+02  1.415500e+02  2.446000e+02

# %%
print("Jumlah Serangan Pada Dataset:")
dataset['Attack Type'].value_counts()
# Out:
# Jumlah Serangan Pada Dataset:
# Attack Type
# DDoS              1221567
# DoS                361461
# Mirai              118537
# BENIGN              73194
# Network Attack      24894
# Recon               13429
# Brute Force           546
# Injection             481
# Malware               139
# Name: count, dtype: int64

# %%
label_map = {
        'BENIGN': 0, 'DDoS': 1, 'DoS': 2, 'Mirai': 3,
        'Network Attack': 4, 'Recon': 5, 'Brute Force': 6,
        'Injection': 7, 'Malware': 8,
    }
dataset["Attack Type"] = dataset["Attack Type"].map(label_map)

# %%
features = dataset.drop('Attack Type',axis=1)
labels = dataset["Attack Type"]

# %%
scaler = StandardScaler()
features = scaler.fit_transform(features)

# %%
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
print("X_train:",x_train.shape)
print("y_train:",y_train.shape)

print("X_test:",x_test.shape)
print("y_test:",y_test.shape)
# Out:
# X_train: (1451398, 46)
# y_train: (1451398,)
# X_test: (362850, 46)
# y_test: (362850,)

# %%
# Mengubah label menjadi format kategori
y_train_cat = to_categorical(y_train, num_classes=9)
y_test_cat = to_categorical(y_test, num_classes=9)

# %%
# Membuat model Deep Neural Network
model = Sequential()

# Menambahkan layer input dan hidden layers
model.add(Dense(units=128, activation='relu', input_dim=x_train.shape[1]))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=32, activation='relu'))
# Menambahkan layer output
model.add(Dense(units=9, activation='softmax'))  # 9 kelas

# Menyusun model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Melatih model
history = model.fit(x_train, y_train_cat, epochs=5, batch_size=64, validation_data=(x_test, y_test_cat))

# Evaluasi model
loss, accuracy = model.evaluate(x_test, y_test_cat)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")

# Prediksi menggunakan model
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Menampilkan confusion matrix dan classification report
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_classes))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_classes))
# Out:
# 2025-07-07 12:25:53.633899: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-07 12:25:53.634281: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Epoch 1/5
# 22679/22679 [==============================] - 29s 1ms/step - loss: 0.2231 - accuracy: 0.9054 - val_loss: 0.0581 - val_accuracy: 0.9807
# Epoch 2/5
# 22679/22679 [==============================] - 29s 1ms/step - loss: 0.0562 - accuracy: 0.9806 - val_loss: 0.0444 - val_accuracy: 0.9851
# Epoch 3/5
# 22679/22679 [==============================] - 28s 1ms/step - loss: 0.0438 - accuracy: 0.9847 - val_loss: 0.0404 - val_accuracy: 0.9859
# Epoch 4/5
# 22679/22679 [==============================] - 28s 1ms/step - loss: 0.0394 - accuracy: 0.9860 - val_loss: 0.0374 - val_accuracy: 0.9865
# Epoch 5/5
# 22679/22679 [==============================] - 27s 1ms/step - loss: 0.0375 - accuracy: 0.9869 - val_loss: 0.0414 - val_accuracy: 0.9875
# 11340/11340 [==============================] - 9s 789us/step - loss: 0.0414 - accuracy: 0.9875
# Test Loss: 0.04138980060815811
# Test Accuracy: 0.987490713596344
# 11340/11340 [==============================] - 8s 673us/step
# Confusion Matrix:
# [[ 14283     34      0      1    263     48      0      0      0]
#  [     4 244188    215      9     16      1      0      0      0]
#  [     0    221  71711      5      6      0      0      0      0]
#  [     2     90      2  23695      5      0      0      0      0]
#  [  1649     87     47      5   3168     81      0      0      0]
#  [  1145     20      0      0    336   1266      0      0      0]
#  [    66     13      0      0     18     13      0      0      0]
#  [    66      2      0      0     34      8      0      0      0]
#  [    11      0      0      0     15      1      0      0      0]]
#
# Classification Report:
# /home/mbc/thesissatria/fllib/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbc/thesissatria/fllib/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90     14629
#            1       1.00      1.00      1.00    244433
#            2       1.00      1.00      1.00     71943
#            3       1.00      1.00      1.00     23794
#            4       0.82      0.63      0.71      5037
#            5       0.89      0.46      0.61      2767
#            6       0.00      0.00      0.00       110
#            7       0.00      0.00      0.00       110
#            8       0.00      0.00      0.00        27
#
#     accuracy                           0.99    362850
#    macro avg       0.62      0.56      0.58    362850
# weighted avg       0.99      0.99      0.99    362850
# /home/mbc/thesissatria/fllib/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Membuat confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Membuat plot confusion matrix menggunakan seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label_map.keys(), yticklabels=label_map.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
